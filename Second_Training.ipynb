# %% [markdown]
# # Library Import

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import shutil
import zipfile
import os
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, LSTM, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import AdamW, RMSprop
from tensorflow.keras.optimizers.schedules import CosineDecayRestarts
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
from google.colab import drive

# %% [markdown]
# # Data Load

# %%
# Mount Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/DATASET .

# %% [markdown]
# # Data Preprocessing

# %%
train_dir = "/content/DATASET/TRAIN/"
test_dir = "/content/DATASET/TEST/"

# %%
img_width = 224
img_height = 224
batch_size = 32
model_dir = "./model"
checkpoint = "model_checkpoint_best_.keras"
checkpoint_path = os.path.join(model_dir, checkpoint)

# %%
os.makedirs(model_dir, exist_ok=True)

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.25,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode="nearest",
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical",
    subset="training",
    shuffle="True"
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical",
    subset="validation",
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False,
)
# Out:
# Found 1424 images belonging to 26 classes.
# Found 351 images belonging to 26 classes.
# Found 208 images belonging to 26 classes.

# %%
labels = train_generator.classes
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

# %%
class_weights = dict(enumerate(class_weights))

# %%
print(train_generator.class_indices)
print(train_generator.samples)
# Out:
# {'Aceh_Pintu_Aceh': 0, 'Bali_Barong': 1, 'Bali_Merak': 2, 'DKI_Ondel_Ondel': 3, 'Jawa_Barat_Megamendung': 4, 'Jawa_Tengah_Batik_Lasem': 5, 'Jawa_Timur_Pring': 6, 'Kalimantan_Barat_Insang': 7, 'Kalimantan_Dayak': 8, 'Lampung_Gajah': 9, 'Madura_Mataketeran': 10, 'Maluku_Pala': 11, 'NTB_Lumbung': 12, 'Palembang_Songket': 13, 'Papua_Asmat': 14, 'Papua_Cendrawasih': 15, 'Papua_Tifa': 16, 'Solo_Parang': 17, 'Solo_Sidoluhur': 18, 'Solo_Sogan': 19, 'Solo_Truntum': 20, 'Sulawesi_Selatan_Lontara': 21, 'Sumatera_Barat_Rumah_Minang': 22, 'Sumatera_Utara_Boraspati': 23, 'Yogyakarta_Kawung': 24, 'Yogyakarta_Sidomukti': 25}
# 1424

# %% [markdown]
# # Model Initialization

# %%
base_model = EfficientNetB0(include_top=False, input_shape=(img_width, img_height, 3), weights='imagenet')
base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dropout(0.5),
    Dense(256, activation='relu', kernel_regularizer=l2(1e-4)),
    BatchNormalization(),
    Dropout(0.5),
    Dense(train_generator.num_classes, activation='softmax', kernel_regularizer=l2(1e-4))
])

# %%
lr_schedule = CosineDecayRestarts(
    initial_learning_rate=1e-4,
    first_decay_steps=5,
    t_mul=2.0,
    m_mul=0.9,
    alpha=1e-6
)

for layer in base_model.layers[:120]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
# Load checkpoint if exists
if os.path.exists(checkpoint_path):
    print("Checkpoint found. Loading model...")
    model = tf.keras.models.load_model(checkpoint_path)
else:
    print("No checkpoint found. Training model from scratch...")
# Out:
# No checkpoint found. Training model from scratch...

# %%
callbacks = [
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=8),
    ModelCheckpoint(checkpoint_path, monitor="val_accuracy", save_best_only=True, save_weights_only=False, verbose=1),
]

# %% [markdown]
# # Model Training

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    class_weight=class_weights,
    callbacks=callbacks,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1198 - loss: 4.0839
# Epoch 1: val_accuracy improved from -inf to 0.51282, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 180s 4s/step - accuracy: 0.1210 - loss: 4.0728 - val_accuracy: 0.5128 - val_loss: 2.1718 - learning_rate: 0.0010
# Epoch 2/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3433 - loss: 2.5294
# Epoch 2: val_accuracy improved from 0.51282 to 0.60969, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 147s 3s/step - accuracy: 0.3436 - loss: 2.5263 - val_accuracy: 0.6097 - val_loss: 1.7676 - learning_rate: 0.0010
# Epoch 3/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4434 - loss: 1.9745
# Epoch 3: val_accuracy improved from 0.60969 to 0.63533, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.4435 - loss: 1.9733 - val_accuracy: 0.6353 - val_loss: 1.4791 - learning_rate: 0.0010
# Epoch 4/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5173 - loss: 1.6691
# Epoch 4: val_accuracy improved from 0.63533 to 0.66382, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.5172 - loss: 1.6688 - val_accuracy: 0.6638 - val_loss: 1.2898 - learning_rate: 0.0010
# Epoch 5/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5529 - loss: 1.4334
# Epoch 5: val_accuracy improved from 0.66382 to 0.69231, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 209s 3s/step - accuracy: 0.5529 - loss: 1.4342 - val_accuracy: 0.6923 - val_loss: 1.1514 - learning_rate: 0.0010
# Epoch 6/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6052 - loss: 1.3380
# Epoch 6: val_accuracy improved from 0.69231 to 0.72080, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.6049 - loss: 1.3390 - val_accuracy: 0.7208 - val_loss: 1.0662 - learning_rate: 0.0010
# Epoch 7/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6154 - loss: 1.2832
# Epoch 7: val_accuracy did not improve from 0.72080
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 146s 3s/step - accuracy: 0.6155 - loss: 1.2822 - val_accuracy: 0.7208 - val_loss: 0.9918 - learning_rate: 0.0010
# Epoch 8/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6522 - loss: 1.1875
# Epoch 8: val_accuracy did not improve from 0.72080
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.6520 - loss: 1.1876 - val_accuracy: 0.7179 - val_loss: 0.9958 - learning_rate: 0.0010
# Epoch 9/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6712 - loss: 1.0813
# Epoch 9: val_accuracy improved from 0.72080 to 0.74644, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 157s 3s/step - accuracy: 0.6709 - loss: 1.0814 - val_accuracy: 0.7464 - val_loss: 0.9249 - learning_rate: 0.0010
# Epoch 10/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6657 - loss: 0.9873
# Epoch 10: val_accuracy improved from 0.74644 to 0.76068, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 158s 4s/step - accuracy: 0.6653 - loss: 0.9889 - val_accuracy: 0.7607 - val_loss: 0.8942 - learning_rate: 0.0010
# Epoch 11/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6836 - loss: 0.9760
# Epoch 11: val_accuracy did not improve from 0.76068
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 146s 3s/step - accuracy: 0.6833 - loss: 0.9763 - val_accuracy: 0.7350 - val_loss: 0.9223 - learning_rate: 0.0010
# Epoch 12/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6713 - loss: 0.9858
# Epoch 12: val_accuracy improved from 0.76068 to 0.77778, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 149s 3s/step - accuracy: 0.6714 - loss: 0.9864 - val_accuracy: 0.7778 - val_loss: 0.8286 - learning_rate: 0.0010
# Epoch 13/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6877 - loss: 0.9392
# Epoch 13: val_accuracy did not improve from 0.77778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 201s 3s/step - accuracy: 0.6877 - loss: 0.9401 - val_accuracy: 0.7635 - val_loss: 0.7992 - learning_rate: 0.0010
# Epoch 14/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7061 - loss: 0.8777
# Epoch 14: val_accuracy improved from 0.77778 to 0.78063, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 162s 4s/step - accuracy: 0.7060 - loss: 0.8786 - val_accuracy: 0.7806 - val_loss: 0.7803 - learning_rate: 0.0010
# Epoch 15/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7248 - loss: 0.8264
# Epoch 15: val_accuracy improved from 0.78063 to 0.78348, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - accuracy: 0.7244 - loss: 0.8265 - val_accuracy: 0.7835 - val_loss: 0.7787 - learning_rate: 0.0010
# Epoch 16/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7120 - loss: 0.8650
# Epoch 16: val_accuracy improved from 0.78348 to 0.78917, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 147s 3s/step - accuracy: 0.7119 - loss: 0.8651 - val_accuracy: 0.7892 - val_loss: 0.7763 - learning_rate: 0.0010
# Epoch 17/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7108 - loss: 0.8243
# Epoch 17: val_accuracy improved from 0.78917 to 0.79487, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 147s 3s/step - accuracy: 0.7111 - loss: 0.8242 - val_accuracy: 0.7949 - val_loss: 0.7983 - learning_rate: 0.0010
# Epoch 18/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7331 - loss: 0.7974
# Epoch 18: val_accuracy did not improve from 0.79487
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.7330 - loss: 0.7981 - val_accuracy: 0.7806 - val_loss: 0.8181 - learning_rate: 0.0010
# Epoch 19/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7373 - loss: 0.7775
# Epoch 19: val_accuracy improved from 0.79487 to 0.80912, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 149s 3s/step - accuracy: 0.7372 - loss: 0.7772 - val_accuracy: 0.8091 - val_loss: 0.7391 - learning_rate: 0.0010
# Epoch 20/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7709 - loss: 0.7764
# Epoch 20: val_accuracy did not improve from 0.80912
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.7706 - loss: 0.7764 - val_accuracy: 0.7835 - val_loss: 0.7984 - learning_rate: 0.0010
# Epoch 21/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7591 - loss: 0.7151
# Epoch 21: val_accuracy did not improve from 0.80912
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.7591 - loss: 0.7155 - val_accuracy: 0.7778 - val_loss: 0.7416 - learning_rate: 0.0010
# Epoch 22/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7395 - loss: 0.7636
# Epoch 22: val_accuracy did not improve from 0.80912
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.7396 - loss: 0.7637 - val_accuracy: 0.7863 - val_loss: 0.7749 - learning_rate: 0.0010
# Epoch 23/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7809 - loss: 0.6621
# Epoch 23: val_accuracy did not improve from 0.80912
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 147s 3s/step - accuracy: 0.7803 - loss: 0.6637 - val_accuracy: 0.8063 - val_loss: 0.7967 - learning_rate: 0.0010
# Epoch 24/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7413 - loss: 0.8348
# Epoch 24: val_accuracy improved from 0.80912 to 0.81766, saving model to ./model/model_checkpoint_best_.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 159s 4s/step - accuracy: 0.7417 - loss: 0.8333 - val_accuracy: 0.8177 - val_loss: 0.7217 - learning_rate: 0.0010
# Epoch 25/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7924 - loss: 0.6225
# Epoch 25: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 157s 3s/step - accuracy: 0.7920 - loss: 0.6235 - val_accuracy: 0.8034 - val_loss: 0.7680 - learning_rate: 0.0010
# Epoch 26/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7817 - loss: 0.7190
# Epoch 26: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 149s 3s/step - accuracy: 0.7814 - loss: 0.7188 - val_accuracy: 0.8177 - val_loss: 0.7276 - learning_rate: 0.0010
# Epoch 27/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7744 - loss: 0.6605
# Epoch 27: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 146s 3s/step - accuracy: 0.7745 - loss: 0.6605 - val_accuracy: 0.8063 - val_loss: 0.7254 - learning_rate: 0.0010
# Epoch 28/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7724 - loss: 0.6844
# Epoch 28: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 147s 3s/step - accuracy: 0.7724 - loss: 0.6853 - val_accuracy: 0.7920 - val_loss: 0.8485 - learning_rate: 0.0010
# Epoch 29/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7939 - loss: 0.6256
# Epoch 29: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 147s 3s/step - accuracy: 0.7938 - loss: 0.6261 - val_accuracy: 0.8006 - val_loss: 0.7905 - learning_rate: 0.0010
# Epoch 30/30
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7758 - loss: 0.6904
# Epoch 30: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 148s 3s/step - accuracy: 0.7760 - loss: 0.6903 - val_accuracy: 0.7977 - val_loss: 0.7740 - learning_rate: 0.0010

# %%
# Fine-tuning
fine_tune_at = 200  # Unfreeze layers from 200 onwards
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False
for layer in base_model.layers[fine_tune_at:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history_fine_tune = model.fit(
    train_generator,
    epochs=20,
    validation_data=validation_generator,
    callbacks=callbacks,
)
# Out:
# Epoch 1/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5842 - loss: 1.4286
# Epoch 1: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 194s 4s/step - accuracy: 0.5843 - loss: 1.4285 - val_accuracy: 0.8063 - val_loss: 0.6986 - learning_rate: 1.0000e-05
# Epoch 2/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6129 - loss: 1.3699
# Epoch 2: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 178s 4s/step - accuracy: 0.6127 - loss: 1.3702 - val_accuracy: 0.7977 - val_loss: 0.7959 - learning_rate: 1.0000e-05
# Epoch 3/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6443 - loss: 1.2646
# Epoch 3: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 179s 4s/step - accuracy: 0.6443 - loss: 1.2651 - val_accuracy: 0.7863 - val_loss: 0.7618 - learning_rate: 1.0000e-05
# Epoch 4/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6299 - loss: 1.2973
# Epoch 4: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 168s 4s/step - accuracy: 0.6297 - loss: 1.2978 - val_accuracy: 0.7778 - val_loss: 0.8284 - learning_rate: 1.0000e-05
# Epoch 5/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6426 - loss: 1.2898
# Epoch 5: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 167s 4s/step - accuracy: 0.6426 - loss: 1.2903 - val_accuracy: 0.7920 - val_loss: 0.8602 - learning_rate: 1.0000e-05
# Epoch 6/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6266 - loss: 1.3371
# Epoch 6: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 168s 4s/step - accuracy: 0.6268 - loss: 1.3367 - val_accuracy: 0.7949 - val_loss: 0.8025 - learning_rate: 1.0000e-05
# Epoch 7/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6521 - loss: 1.2028
# Epoch 7: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 181s 4s/step - accuracy: 0.6521 - loss: 1.2036 - val_accuracy: 0.7835 - val_loss: 0.8159 - learning_rate: 1.0000e-05
# Epoch 8/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6796 - loss: 1.1501
# Epoch 8: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 179s 4s/step - accuracy: 0.6795 - loss: 1.1507 - val_accuracy: 0.7664 - val_loss: 0.8482 - learning_rate: 1.0000e-05
# Epoch 9/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6677 - loss: 1.1952
# Epoch 9: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 214s 4s/step - accuracy: 0.6679 - loss: 1.1952 - val_accuracy: 0.8034 - val_loss: 0.8127 - learning_rate: 1.0000e-05
# Epoch 10/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6762 - loss: 1.1523
# Epoch 10: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 183s 4s/step - accuracy: 0.6761 - loss: 1.1526 - val_accuracy: 0.7692 - val_loss: 0.8484 - learning_rate: 5.0000e-06
# Epoch 11/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6625 - loss: 1.1854
# Epoch 11: val_accuracy did not improve from 0.81766
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 174s 4s/step - accuracy: 0.6626 - loss: 1.1854 - val_accuracy: 0.7892 - val_loss: 0.8249 - learning_rate: 5.0000e-06

# %% [markdown]
# # Evaluation

# %%
validation_loss, validation_accuracy = model.evaluate(validation_generator)
print(f"Validation Loss: {validation_loss:.3f}, Validation Accuracy: {validation_accuracy:.2%}")

test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Loss: {test_loss:.3f}, Test Accuracy: {test_accuracy:.2%}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.8281 - loss: 0.6731
# Validation Loss: 0.707, Validation Accuracy: 80.91%
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.8927 - loss: 0.4536
# Test Loss: 0.429, Test Accuracy: 89.42%

# %%
preds = model.predict(test_generator)
y_pred = np.argmax(preds, axis=1)
y_true = test_generator.classes

print(classification_report(y_true, y_pred, target_names=list(test_generator.class_indices.keys())))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step
#                              precision    recall  f1-score   support
#
#             Aceh_Pintu_Aceh       1.00      1.00      1.00         8
#                 Bali_Barong       1.00      0.75      0.86         8
#                  Bali_Merak       1.00      0.88      0.93         8
#             DKI_Ondel_Ondel       0.89      1.00      0.94         8
#      Jawa_Barat_Megamendung       1.00      0.88      0.93         8
#     Jawa_Tengah_Batik_Lasem       1.00      0.75      0.86         8
#            Jawa_Timur_Pring       0.70      0.88      0.78         8
#     Kalimantan_Barat_Insang       1.00      0.75      0.86         8
#            Kalimantan_Dayak       1.00      1.00      1.00         8
#               Lampung_Gajah       1.00      1.00      1.00         8
#          Madura_Mataketeran       1.00      0.88      0.93         8
#                 Maluku_Pala       0.89      1.00      0.94         8
#                 NTB_Lumbung       0.89      1.00      0.94         8
#           Palembang_Songket       0.88      0.88      0.88         8
#                 Papua_Asmat       0.89      1.00      0.94         8
#           Papua_Cendrawasih       0.73      1.00      0.84         8
#                  Papua_Tifa       1.00      1.00      1.00         8
#                 Solo_Parang       1.00      1.00      1.00         8
#              Solo_Sidoluhur       0.67      1.00      0.80         8
#                  Solo_Sogan       0.71      0.62      0.67         8
#                Solo_Truntum       1.00      0.88      0.93         8
#    Sulawesi_Selatan_Lontara       0.89      1.00      0.94         8
# Sumatera_Barat_Rumah_Minang       1.00      1.00      1.00         8
#    Sumatera_Utara_Boraspati       1.00      1.00      1.00         8
#           Yogyakarta_Kawung       1.00      1.00      1.00         8
#        Yogyakarta_Sidomukti       0.60      0.38      0.46         8
#
#                    accuracy                           0.90       208
#                   macro avg       0.91      0.90      0.90       208
#                weighted avg       0.91      0.90      0.90       208

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Initial Train Loss")
plt.plot(history.history["val_loss"], label="Initial Val Loss")
plt.legend()
plt.title("Loss Curve")

plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Initial Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Initial Val Accuracy")
plt.legend()
plt.title("Accuracy Curve")

plt.show()

# %%
predictions = model.predict(test_generator)
class_labels = list(test_generator.class_indices.keys())
true_indices = test_generator.classes
predicted_indices = np.argmax(predictions, axis=1)
prediction_confidences = np.max(predictions, axis=1)

# Visualization function
def visualize_predictions(indices, title, rows=2, cols=5):
    fig, axes = plt.subplots(rows, cols, figsize=(15, 6))
    for i, idx in enumerate(indices):
        img_path = test_generator.filepaths[idx]
        img = plt.imread(img_path)
        true_label = class_labels[true_indices[idx]]
        predicted_label = class_labels[predicted_indices[idx]]
        confidence = prediction_confidences[idx] * 100

        ax = axes[i // cols, i % cols]
        ax.imshow(img)
        ax.axis("off")
        ax.set_title(f"True: {true_label}\nPred: {predicted_label}\nConf: {confidence:.2f}%", fontsize=10)

    plt.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

# Lowest and highest confidence predictions
low_conf_indices = np.argsort(prediction_confidences)[:10]
high_conf_indices = np.argsort(prediction_confidences)[-10:][::-1]

visualize_predictions(low_conf_indices, "Lowest 10 Predictions by Confidence")
visualize_predictions(high_conf_indices, "Top 10 Predictions by Confidence")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step

# %% [markdown]
# # Save Model

# %%
pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.22.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: flax>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.10.6)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (6.5.2)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.2)
# Requirement already satisfied: jaxlib>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.1)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tf-keras>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.11.0)
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.16.1)
# Collecting packaging~=23.1 (from tensorflowjs)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (2.0.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.11.13)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.74)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (4.13.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.9)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (1.15.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.11.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.19.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.89)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (1.12.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.12.3)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2025.3.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.21.0)
# Downloading tensorflowjs-4.22.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 2.2 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: packaging, tensorflowjs
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 3.32.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# Successfully installed packaging-23.2 tensorflowjs-4.22.0

# %%
import tensorflowjs as tfjs

os.makedirs('model_saved', exist_ok=True)
os.makedirs('tfjs_model', exist_ok=True)

# SavedModel
model.export('model_saved')  # or model.save('model_saved') for Keras Sequential/Functional models

# TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)

# TFJS
tfjs_target_dir = 'tfjs_model'
tfjs.converters.save_keras_model(model, tfjs_target_dir)

# Create ZIP file
with zipfile.ZipFile('models_bundle.zip', 'w', zipfile.ZIP_DEFLATED) as zipf:
    # Add SavedModel directory
    for root, dirs, files in os.walk('model_saved'):
        for file in files:
            zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), '.'))

    # Add TFLite model file
    zipf.write('model.tflite')

    # Add TFJS model directory
    for root, dirs, files in os.walk(tfjs_target_dir):
        for file in files:
            zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), '.'))
# Out:
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>
# Saved artifact at 'model_saved'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_238')
# Output Type:
#   TensorSpec(shape=(None, 26), dtype=tf.float32, name=None)
# Captures:
#   133073697882768: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   133073697883152: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   133073824485968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824485392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824486928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824483472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824489808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824484240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824491728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824490384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824491536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824490576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824492880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824494416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824494608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824495376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824493456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824496144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824496912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824495760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824495568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824496720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818846224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818845264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824494992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818845456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818847568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818846800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818846032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818847184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818848528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818849680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818849872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818850064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818850832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818852560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818853520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818853136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818854480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818853712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818855440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818855056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818856400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818855632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818850448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818857360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818857552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818855824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818857936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818853904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818859088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818859856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818858704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818858512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818859280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818861200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792008656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818860432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818861008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792009808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792008464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792010768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792010000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792009040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792011728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792011920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792010192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792012304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792009424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792013456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792014224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792013072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792012880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792015184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792014800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792016144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792015376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792012112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792017104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792016720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792018064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792017296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792009232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792019024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792019216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792017488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792019600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792021328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792013648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792021520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792020752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792015568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792019984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792022672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792023824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792023056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792022864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792023632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792533136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792532560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792024400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792022288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792534672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792534864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792533520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792535248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792533328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792536400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792537168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792536016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792535824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792538128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792537744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792539088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792538320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792535056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792540048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792539664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792541008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792540240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792532752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792541968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792542160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792540432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792542544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792538512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792543696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792544464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792543312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792543120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792543888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792545808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792546768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792546000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792544656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792547728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792546192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792545040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792547920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792545616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792548496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790911696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790910928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790911888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790912272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790913040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790913808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790912656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790912464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790913232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790915152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790916112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790915344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790914000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790917072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790916688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790918032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790917264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790914960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790918992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790919184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790917456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790919568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790915536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790920720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790921488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790920336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790920144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790922448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790922064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790923408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790922640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790919376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790924368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790923984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790925328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790924560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790914384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790926288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790925520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790926480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790922832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790925904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791337872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791336912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791337680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791336720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791337488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791339792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791340752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791339984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791338640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791341712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791341328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791342672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791341904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791339600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791343632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791343824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791342096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791344208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791340176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791345360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791346128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791344976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791344784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791345552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791347472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791348432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791347664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791346320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791349392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791349008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791350352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791349584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791347280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791351312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791351504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791349776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791350928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791352272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791795664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791795856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791351696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791351888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791797200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791796816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791798160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791797392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791796432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791799120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791798736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791800080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791799312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791795472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791801040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791801232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791799504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791801616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791797584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791802768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791803536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791802384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791802192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791802960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791806416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791804688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791804112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791806992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791803728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791801424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791805840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791805456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791805648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791808720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791808912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791806800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791809296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791805072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791810448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791811408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791810064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791809872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791809104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697408400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697407440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697408208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697407248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697409936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697409552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697410896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697410128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697407632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697411856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697412048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697410320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697412432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697408016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697413584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697414352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697413200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697413008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697408784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697415888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697416848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697416080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697415312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697417808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697417424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697418768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697418000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697415696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697419728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697419920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697418192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697420304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697416272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697421456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697422224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697421072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697420880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697423184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697420112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697882192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697421648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697415504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697885072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697885648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697884688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697884304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697886800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697887376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697887568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697886416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697883536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697887184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697889104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697889680: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved artifact at '/tmp/tmp713s6p2o'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_238')
# Output Type:
#   TensorSpec(shape=(None, 26), dtype=tf.float32, name=None)
# Captures:
#   133073697882768: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   133073697883152: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   133073824485968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824485392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824486928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824483472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824489808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824484240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824491728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824490384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824491536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824490576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824492880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824494416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824494608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824495376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824493456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824496144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824496912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824495760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824495568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824496720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818846224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818845264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073824494992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818845456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818847568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818846800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818846032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818847184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818848528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818849680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818849872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818850064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818850832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818852560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818853520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818853136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818854480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818853712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818851600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818855440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818855056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818856400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818855632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818850448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818857360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818857552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818855824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818857936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818853904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818859088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818859856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818858704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818858512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818859280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818861200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792008656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818860432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073818861008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792009808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792008464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792010768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792010000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792009040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792011728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792011920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792010192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792012304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792009424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792013456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792014224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792013072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792012880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792015184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792014800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792016144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792015376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792012112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792017104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792016720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792018064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792017296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792009232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792019024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792019216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792017488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792019600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792021328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792013648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792021520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792020752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792015568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792019984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792022672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792023824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792023056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792022864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792023632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792533136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792532560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792024400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792022288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792534672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792534864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792533520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792535248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792533328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792536400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792537168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792536016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792535824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792538128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792537744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792539088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792538320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792535056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792540048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792539664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792541008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792540240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792532752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792541968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792542160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792540432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792542544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792538512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792543696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792544464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792543312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792543120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792543888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792545808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792546768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792546000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792544656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792547728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792546192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792545040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792547920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792545616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073792548496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790911696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790910928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790911888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790912272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790913040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790913808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790912656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790912464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790913232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790915152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790916112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790915344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790914000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790917072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790916688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790918032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790917264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790914960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790918992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790919184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790917456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790919568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790915536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790920720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790921488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790920336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790920144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790922448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790922064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790923408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790922640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790919376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790924368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790923984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790925328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790924560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790914384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790926288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790925520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790926480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790922832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073790925904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791337872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791336912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791337680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791336720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791337488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791339792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791340752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791339984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791338640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791341712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791341328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791342672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791341904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791339600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791343632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791343824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791342096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791344208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791340176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791345360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791346128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791344976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791344784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791345552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791347472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791348432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791347664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791346320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791349392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791349008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791350352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791349584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791347280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791351312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791351504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791349776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791350928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791352272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791795664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791795856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791351696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791351888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791797200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791796816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791798160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791797392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791796432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791799120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791798736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791800080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791799312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791795472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791801040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791801232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791799504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791801616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791797584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791802768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791803536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791802384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791802192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791802960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791806416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791804688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791804112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791806992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791803728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791801424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791805840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791805456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791805648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791808720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791808912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791806800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791809296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791805072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791810448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791811408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791810064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791809872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073791809104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697408400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697407440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697408208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697407248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697409936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697409552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697410896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697410128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697407632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697411856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697412048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697410320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697412432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697408016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697413584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697414352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697413200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697413008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697408784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697415888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697416848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697416080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697415312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697417808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697417424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697418768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697418000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697415696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697419728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697419920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697418192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697420304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697416272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697421456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697422224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697421072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697420880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697423184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697420112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697882192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697421648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697415504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697885072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697885648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697884688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697884304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697886800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697887376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697887568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697886416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697883536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697887184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697889104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133073697889680: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# failed to lookup keras version from the file,
#     this is likely a weight only file
# weight normalization/count with shape () and dtype int64 was auto converted to the type int32
